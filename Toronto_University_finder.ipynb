# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Folium installed
# Libraries imported.

# %%
# !pip install geopy
from geopy.geocoders import Nominatim
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)

# %%
CLIENT_ID = 'HTEQQEAY2ZKJEFL1UTEQMSBQKNTDMEJ4TF4DBLCLGFS2D0YK' # your Foursquare ID
CLIENT_SECRET = 'FYIR54J22WICJ0RA0XBYE4C0SX20JJADKI3XFDODWE4ICGHZ' # your Foursquare Secret
VERSION = '20201122'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HTEQQEAY2ZKJEFL1UTEQMSBQKNTDMEJ4TF4DBLCLGFS2D0YK
# CLIENT_SECRET:FYIR54J22WICJ0RA0XBYE4C0SX20JJADKI3XFDODWE4ICGHZ

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %%
search_query = 'University'
radius = '2000'
print(search_query + ' .... OK!' + radius)
# Out:
# University .... OK!2000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HTEQQEAY2ZKJEFL1UTEQMSBQKNTDMEJ4TF4DBLCLGFS2D0YK&client_secret=FYIR54J22WICJ0RA0XBYE4C0SX20JJADKI3XFDODWE4ICGHZ&ll=43.6534817,-79.3839347&v=20201122&query=University&radius=2000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fba83423023093e62b20fd1'},
#  'response': {'venues': [{'id': '4cd044c29d87224bf129543b',
#     'name': 'University Centre Gym',
#     'location': {'lat': 43.653571,
#      'lng': -79.386979,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653571,
#        'lng': -79.386979}],
#      'distance': 245,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ad4c05ef964a52097f620e3',
#     'name': 'University of Toronto',
#     'location': {'address': "27 King's College Cir",
#      'crossStreet': "at King's College Rd",
#      'lat': 43.6624934706167,
#      'lng': -79.39521976633822,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6624934706167,
#        'lng': -79.39521976633822}],
#      'distance': 1353,
#      'postalCode': 'M5S 1A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["27 King's College Cir (at King's College Rd)",
#       'Toronto ON M5S 1A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57112483'},
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c45c6c6da2176b09543637a',
#     'name': 'University Centre',
#     'location': {'address': '393 University Ave.',
#      'crossStreet': 'at Armoury St.',
#      'lat': 43.65390719043468,
#      'lng': -79.38676401996314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65390719043468,
#        'lng': -79.38676401996314}],
#      'distance': 232,
#      'postalCode': 'M7A 2K1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['393 University Ave. (at Armoury St.)',
#       'Toronto ON M7A 2K1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c6062b612e5c9286e131f4c',
#     'name': 'Dundas University Health Clinic',
#     'location': {'address': '104-438 University Avenue',
#      'lat': 43.65419587934101,
#      'lng': -79.38816564112626,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65419587934101,
#        'lng': -79.38816564112626}],
#      'distance': 349,
#      'postalCode': 'M4P 2K8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['104-438 University Avenue',
#       'Toronto ON M4P 2K8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e6565fb1850e238d7048495',
#     'name': 'University Avenue Plaza',
#     'location': {'address': 'University Avenue',
#      'crossStreet': 'btwn Richmond & College',
#      'lat': 43.652694706867656,
#      'lng': -79.38721761495859,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652694706867656,
#        'lng': -79.38721761495859}],
#      'distance': 278,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['University Avenue (btwn Richmond & College)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '5633a320498e59191a412f3d',
#     'name': 'University of Toronto Dentistry Faculty',
#     'location': {'address': '124 Edward Street',
#      'lat': 43.656260403463875,
#      'lng': -79.38714265823363,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656260403463875,
#        'lng': -79.38714265823363}],
#      'distance': 403,
#      'postalCode': 'M5G 2L3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['124 Edward Street',
#       'Toronto ON M5G 2L3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4b13d2cff964a5207f9923e3',
#     'name': '480 University Ave',
#     'location': {'address': '480 University Ave',
#      'crossStreet': 'Dundas',
#      'lat': 43.655099313141456,
#      'lng': -79.38864768279834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655099313141456,
#        'lng': -79.38864768279834}],
#      'distance': 420,
#      'postalCode': 'M5G 1V2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['480 University Ave (Dundas)',
#       'Toronto ON M5G 1V2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4d5d275fff226a3110517e69',
#     'name': '438 University Ave',
#     'location': {'address': '438 University Ave',
#      'crossStreet': 'at Dundas St W',
#      'lat': 43.654295708304566,
#      'lng': -79.38841537026018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654295708304566,
#        'lng': -79.38841537026018}],
#      'distance': 372,
#      'postalCode': 'M5G 2K8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['438 University Ave (at Dundas St W)',
#       'Toronto ON M5G 2K8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c655857f67ec928e7485727',
#     'name': '393 University Ave',
#     'location': {'address': '393 University Ave',
#      'lat': 43.65375248805427,
#      'lng': -79.38814953976639,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65375248805427,
#        'lng': -79.38814953976639}],
#      'distance': 340,
#      'postalCode': 'M5G 1E6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['393 University Ave',
#       'Toronto ON M5G 1E6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c053af4187ec928411db87b',
#     'name': 'Queen & University',
#     'location': {'address': 'Queen St W',
#      'crossStreet': '& University Ave',
#      'lat': 43.65083280275225,
#      'lng': -79.38685780107795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65083280275225,
#        'lng': -79.38685780107795}],
#      'distance': 377,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Queen St W (& University Ave)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '502ebc1ce4b0d68f376457b9',
#     'name': 'Ryerson University Security Centre',
#     'location': {'address': '111 Bond St.',
#      'lat': 43.65298107973972,
#      'lng': -79.37834049268542,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65298107973972,
#        'lng': -79.37834049268542}],
#      'distance': 454,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Bond St.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4f0c5654e4b087b6f750937a',
#     'name': 'Lakehead University Book Store',
#     'location': {'address': '500 University Avenue',
#      'lat': 43.65542796114875,
#      'lng': -79.38900173416671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65542796114875,
#        'lng': -79.38900173416671}],
#      'distance': 462,
#      'cc': 'CA',
#      'city': 'Orillia',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['500 University Avenue', 'Orillia ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '51433917e4b03cf305c043d3',
#     'name': 'University & Wellington',
#     'location': {'lat': 43.64638522569841,
#      'lng': -79.38487814017589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64638522569841,
#        'lng': -79.38487814017589}],
#      'distance': 793,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e243f4fe4cdf68591a0df9d',
#     'name': '181 University Ave',
#     'location': {'lat': 43.64928171051231,
#      'lng': -79.3857877029784,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64928171051231,
#        'lng': -79.3857877029784}],
#      'distance': 490,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c48b7c1b5eec9b63200caa3',
#     'name': 'University Eye Clinic',
#     'location': {'address': '700 University Ave, Suite 3',
#      'crossStreet': 'College Street',
#      'lat': 43.65927999991696,
#      'lng': -79.39028146626319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65927999991696,
#        'lng': -79.39028146626319}],
#      'distance': 823,
#      'postalCode': 'M5G 1Z5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['700 University Ave, Suite 3 (College Street)',
#       'Toronto ON M5G 1Z5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d177941735',
#       'name': "Doctor's Office",
#       'pluralName': "Doctor's Offices",
#       'shortName': "Doctor's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ae85d05f964a520e2ae21e3',
#     'name': '505 University Ave.',
#     'location': {'address': '505 University Ave.',
#      'lat': 43.65617732807896,
#      'lng': -79.38854927968431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65617732807896,
#        'lng': -79.38854927968431}],
#      'distance': 477,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['505 University Ave.', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4afc9ba3f964a5205e2422e3',
#     'name': 'Ryerson University Department of Architectural Science',
#     'location': {'address': '325 Church St., ARC-203',
#      'crossStreet': 'at Ryerson University',
#      'lat': 43.659306870781336,
#      'lng': -79.37809550264521,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.659306870781336,
#        'lng': -79.37809550264521}],
#      'distance': 801,
#      'postalCode': 'M5B 2K3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['325 Church St., ARC-203 (at Ryerson University)',
#       'Toronto ON M5B 2K3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4b82c2d4f964a52010e330e3',
#     'name': 'Ryerson University Campus Store',
#     'location': {'address': '17 Gould St.',
#      'crossStreet': 'at Victoria St.',
#      'lat': 43.65750025281336,
#      'lng': -79.38004110951907,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65750025281336,
#        'lng': -79.38004110951907}],
#      'distance': 546,
#      'postalCode': 'M5B 2K3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['17 Gould St. (at Victoria St.)',
#       'Toronto ON M5B 2K3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1b1941735',
#       'name': 'College Bookstore',
#       'pluralName': 'College Bookstores',
#       'shortName': 'College Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ad4c064f964a52065f820e3',
#     'name': 'Ontario College of Art and Design University (OCADU)',
#     'location': {'address': '100 McCaul St',
#      'crossStreet': 'at Dundas St W',
#      'lat': 43.65280251171013,
#      'lng': -79.3910743699992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65280251171013,
#        'lng': -79.3910743699992}],
#      'distance': 579,
#      'postalCode': 'M5T 1W1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 McCaul St (at Dundas St W)',
#       'Toronto ON M5T 1W1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c4469cb8c1f20a1de563c99',
#     'name': 'King & University',
#     'location': {'address': 'King',
#      'crossStreet': 'University',
#      'lat': 43.64781757077785,
#      'lng': -79.38496827020198,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64781757077785,
#        'lng': -79.38496827020198}],
#      'distance': 635,
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['King (University)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e5c344f1520cd7bd644f933',
#     'name': 'Simulation Lab @ Ryerson University',
#     'location': {'address': '415 Yonge Street, 3rd Floor',
#      'crossStreet': 'Gerrard St. E. & Yonge St.',
#      'lat': 43.65974555361321,
#      'lng': -79.38204109668732,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65974555361321,
#        'lng': -79.38204109668732}],
#      'distance': 713,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['415 Yonge Street, 3rd Floor (Gerrard St. E. & Yonge St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a5941735',
#       'name': 'College Lab',
#       'pluralName': 'College Labs',
#       'shortName': 'Lab',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '5254687611d247f32d3bcaf0',
#     'name': '100 University Avenue',
#     'location': {'address': '100 University Avenue',
#      'lat': 43.6471854998311,
#      'lng': -79.38436680171635,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6471854998311,
#        'lng': -79.38436680171635}],
#      'distance': 701,
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 University Avenue', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c850e1b2f1c236ad9e85043',
#     'name': 'University of Toronto Engineering Society',
#     'location': {'address': "10 King's College Rd. - B740",
#      'crossStreet': 'at Galbraith Rd.',
#      'lat': 43.660097244179,
#      'lng': -79.39464374612372,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.660097244179,
#        'lng': -79.39464374612372}],
#      'distance': 1134,
#      'postalCode': 'M5S 3G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["10 King's College Rd. - B740 (at Galbraith Rd.)",
#       'Toronto ON M5S 3G4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ab941735',
#       'name': 'Student Center',
#       'pluralName': 'Student Centers',
#       'shortName': 'Student Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '32884065'},
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4f144a09e4b0456269f68c59',
#     'name': '425 University Avenue',
#     'location': {'address': '425 University Avenue',
#      'crossStreet': 'Dundas St W',
#      'lat': 43.65376907416923,
#      'lng': -79.38394893163043,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65376907416923,
#        'lng': -79.38394893163043}],
#      'distance': 32,
#      'postalCode': 'M5G 1T6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['425 University Avenue (Dundas St W)',
#       'Toronto ON M5G 1T6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4b957655f964a520d2a334e3',
#     'name': "University at St. Michael's College",
#     'location': {'address': 'St Joseph St',
#      'crossStreet': 'Bay',
#      'lat': 43.66571145228362,
#      'lng': -79.38990890018266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66571145228362,
#        'lng': -79.38990890018266}],
#      'distance': 1443,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['St Joseph St (Bay)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4be2a144d27a20a11fee8f5b',
#     'name': 'University Of Toronto Residence Parking Garage',
#     'location': {'address': '89 Chestnut Street',
#      'lat': 43.65418264783643,
#      'lng': -79.3859887795712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65418264783643,
#        'lng': -79.3859887795712}],
#      'distance': 182,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['89 Chestnut Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4d8a79ae6ce6a35de4a26142',
#     'name': 'University College Art Centre',
#     'location': {'crossStreet': 'King College Circle and Tower Rd',
#      'lat': 43.663962206170915,
#      'lng': -79.39538469518658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663962206170915,
#        'lng': -79.39538469518658}],
#      'distance': 1487,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['King College Circle and Tower Rd',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4bfd97014cf820a1c0b0ecf4',
#     'name': 'University of Toronto Arts Centre',
#     'location': {'address': '15 Kings College Circle',
#      'lat': 43.663605383400764,
#      'lng': -79.39515929235343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663605383400764,
#        'lng': -79.39515929235343}],
#      'distance': 1444,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Kings College Circle', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '50b3eee5e4b0ed0fc2780e7b',
#     'name': 'University-Spadina Line',
#     'location': {'lat': 43.66820177496591,
#      'lng': -79.39960127614752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66820177496591,
#        'lng': -79.39960127614752}],
#      'distance': 2068,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1fd931735',
#       'name': 'Metro Station',
#       'pluralName': 'Metro Stations',
#       'shortName': 'Metro',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4bbe3fdd1416a5931ce3f33c',
#     'name': 'University College Residence Office',
#     'location': {'address': '79 St. George street',
#      'lat': 43.66333075902387,
#      'lng': -79.39794655218243,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66333075902387,
#        'lng': -79.39794655218243}],
#      'distance': 1573,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['79 St. George street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ad893f7f964a5207c1221e3',
#     'name': 'University College',
#     'location': {'address': "15 King's College Circle",
#      'crossStreet': 'University of Toronto',
#      'lat': 43.66269528389713,
#      'lng': -79.39606090038882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66269528389713,
#        'lng': -79.39606090038882}],
#      'distance': 1416,
#      'postalCode': 'M5S 3H7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["15 King's College Circle (University of Toronto)",
#       'Toronto ON M5S 3H7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ad7797cf964a520170b21e3',
#     'name': 'Ryerson University',
#     'location': {'address': '350 Victoria St.',
#      'crossStreet': 'at Gould St.',
#      'lat': 43.65793504826254,
#      'lng': -79.38049043443252,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65793504826254,
#        'lng': -79.38049043443252}],
#      'distance': 568,
#      'postalCode': 'M5B 2K3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['350 Victoria St. (at Gould St.)',
#       'Toronto ON M5B 2K3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e395cffb0fb2f7ee8661071',
#     'name': 'University Centre File Room',
#     'location': {'address': '393 university ave',
#      'lat': 43.654095,
#      'lng': -79.387733,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654095,
#        'lng': -79.387733}],
#      'distance': 313,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['393 university ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e395c8862e16ad099f14646',
#     'name': 'University Centre Tenth Floor',
#     'location': {'lat': 43.654099,
#      'lng': -79.387895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654099,
#        'lng': -79.387895}],
#      'distance': 326,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e087c74b3ad23ff54003709',
#     'name': 'University of Liverpool Online Degress - Information Session',
#     'location': {'address': 'Toronto Marriot Downtown Eaton Centre Hotel',
#      'crossStreet': '525 Bay Street',
#      'lat': 43.65658641717643,
#      'lng': -79.38404202461243,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65658641717643,
#        'lng': -79.38404202461243}],
#      'distance': 345,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto Marriot Downtown Eaton Centre Hotel (525 Bay Street)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4fb67e68e4b0a804114ec42a',
#     'name': 'University Ave Island',
#     'location': {'address': '0',
#      'crossStreet': 'Dundas Ave',
#      'lat': 43.654790072474064,
#      'lng': -79.38816053591259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654790072474064,
#        'lng': -79.38816053591259}],
#      'distance': 370,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['0 (Dundas Ave)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4cd0434c7b6854818178c0f8',
#     'name': 'University tobacco Centre',
#     'location': {'address': '481 University Ave',
#      'lat': 43.654769,
#      'lng': -79.388195,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654769,
#        'lng': -79.388195}],
#      'distance': 371,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['481 University Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e7de44a29c294ffa2d4ce89',
#     'name': 'University Ave And Edward St',
#     'location': {'lat': 43.6561251758947,
#      'lng': -79.38788563286427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6561251758947,
#        'lng': -79.38788563286427}],
#      'distance': 433,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4baa40a2f964a520d5573ae3',
#     'name': 'University Club',
#     'location': {'address': '380 university Ave',
#      'lat': 43.65314503023699,
#      'lng': -79.38771090133449,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65314503023699,
#        'lng': -79.38771090133449}],
#      'distance': 306,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['380 university Ave', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e4e92921f6eae4d250d348d',
#     'name': 'University Square',
#     'location': {'lat': 43.650589068574426,
#      'lng': -79.38682762410053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650589068574426,
#        'lng': -79.38682762410053}],
#      'distance': 397,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4c49c1136f1420a1e2e60c56',
#     'name': 'University Convenience',
#     'location': {'address': '481 University Ave.',
#      'crossStreet': 'at Dundas',
#      'lat': 43.6548775434494,
#      'lng': -79.38912749290466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6548775434494,
#        'lng': -79.38912749290466}],
#      'distance': 446,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['481 University Ave. (at Dundas)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4f09cbb2e4b0ca3a5da2e59c',
#     'name': 'University Plaza Gym',
#     'location': {'address': '140 Simcoe St',
#      'crossStreet': 'Richmond And Simcoe',
#      'lat': 43.649792475318804,
#      'lng': -79.38736331482232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649792475318804,
#        'lng': -79.38736331482232}],
#      'distance': 494,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['140 Simcoe St (Richmond And Simcoe)', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '5706a95dcd10b38b56da75d3',
#     'name': '488 University Ave',
#     'location': {'address': '488 University Ave',
#      'crossStreet': 'Dundas St W',
#      'lat': 43.655982,
#      'lng': -79.38856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655982,
#        'lng': -79.38856}],
#      'distance': 465,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['488 University Ave (Dundas St W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '5756b9c4498ea46881c6631c',
#     'name': 'University Avenue',
#     'location': {'lat': 43.657787079302004,
#      'lng': -79.38674202741741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657787079302004,
#        'lng': -79.38674202741741}],
#      'distance': 529,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e3eeac318a83d5b285881d9',
#     'name': 'University Parkette',
#     'location': {'lat': 43.656706385066656,
#      'lng': -79.38889727205434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656706385066656,
#        'lng': -79.38889727205434}],
#      'distance': 537,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '59073d7b780eee19af8852d5',
#     'name': 'University Health Network Spiritual Care Department',
#     'location': {'address': '700 Bay St',
#      'lat': 43.658209,
#      'lng': -79.384962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658209,
#        'lng': -79.384962}],
#      'distance': 532,
#      'postalCode': 'M5G 0A2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['700 Bay St', 'Toronto ON M5G 0A2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d131941735',
#       'name': 'Spiritual Center',
#       'pluralName': 'Spiritual Centers',
#       'shortName': 'Spiritual',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4e53f618fa766dacedec3098',
#     'name': 'University Plaza',
#     'location': {'lat': 43.6493938770396,
#      'lng': -79.38709515637214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6493938770396,
#        'lng': -79.38709515637214}],
#      'distance': 521,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '51b73fd2498e156dd1dd018a',
#     'name': 'Dundas & University',
#     'location': {'address': 'University Ave',
#      'crossStreet': 'Dundas',
#      'lat': 43.65462,
#      'lng': -79.38915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65462,
#        'lng': -79.38915}],
#      'distance': 438,
#      'postalCode': 'M5G 1V1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['University Ave (Dundas)',
#       'Toronto ON M5G 1V1',
#       'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4c',
#       'name': 'Intersection',
#       'pluralName': 'Intersections',
#       'shortName': 'Intersection',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '58445078c7ec6b39be558738',
#     'name': 'University Of Toronto - St. George Campus',
#     'location': {'lat': 43.662655,
#      'lng': -79.39544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.662655,
#        'lng': -79.39544}],
#      'distance': 1378,
#      'postalCode': 'M5S 3H7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5S 3H7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False},
#    {'id': '4ba781a6f964a520f09839e3',
#     'name': 'University Settlement Recreation Centre',
#     'location': {'address': '23 Grange Rd.',
#      'crossStreet': 'Dundas and McCaul',
#      'lat': 43.65213850602077,
#      'lng': -79.39147710800171,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65213850602077,
#        'lng': -79.39147710800171}],
#      'distance': 625,
#      'postalCode': 'M5T 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['23 Grange Rd. (Dundas and McCaul)',
#       'Toronto ON M5T 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1b2941735',
#       'name': 'College Gym',
#       'pluralName': 'College Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1606058818',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  4cd044c29d87224bf129543b            University Centre Gym
# 1  4ad4c05ef964a52097f620e3            University of Toronto
# 2  4c45c6c6da2176b09543637a                University Centre
# 3  4c6062b612e5c9286e131f4c  Dundas University Health Clinic
# 4  4e6565fb1850e238d7048495          University Avenue Plaza
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1606058818    False
# 1  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'U...  v-1606058818    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1606058818    False
# 3  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...  v-1606058818    False
# 4  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...  v-1606058818    False
#
#    location.lat  location.lng  \
# 0     43.653571    -79.386979
# 1     43.662493    -79.395220
# 2     43.653907    -79.386764
# 3     43.654196    -79.388166
# 4     43.652695    -79.387218
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.653571, 'lng':...                245
# 1  [{'label': 'display', 'lat': 43.6624934706167,...               1353
# 2  [{'label': 'display', 'lat': 43.65390719043468...                232
# 3  [{'label': 'display', 'lat': 43.65419587934101...                349
# 4  [{'label': 'display', 'lat': 43.65269470686765...                278
#
#   location.cc location.country  \
# 0          CA           Canada
# 1          CA           Canada
# 2          CA           Canada
# 3          CA           Canada
# 4          CA           Canada
#
#                            location.formattedAddress  \
# 0                                           [Canada]
# 1  [27 King's College Cir (at King's College Rd),...
# 2  [393 University Ave. (at Armoury St.), Toronto...
# 3  [104-438 University Avenue, Toronto ON M4P 2K8...
# 4  [University Avenue (btwn Richmond & College), ...
#
#             location.address     location.crossStreet location.postalCode  \
# 0                        NaN                      NaN                 NaN
# 1      27 King's College Cir     at King's College Rd             M5S 1A1
# 2        393 University Ave.           at Armoury St.             M7A 2K1
# 3  104-438 University Avenue                      NaN             M4P 2K8
# 4          University Avenue  btwn Richmond & College                 NaN
#
#   location.city location.state venuePage.id location.neighborhood
# 0           NaN            NaN          NaN                   NaN
# 1       Toronto             ON     57112483                   NaN
# 2       Toronto             ON          NaN                   NaN
# 3       Toronto             ON          NaN                   NaN
# 4       Toronto             ON          NaN                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                               University Centre Gym
# 1                               University of Toronto
# 2                                   University Centre
# 3                     Dundas University Health Clinic
# 4                             University Avenue Plaza
# 5             University of Toronto Dentistry Faculty
# 6                                  480 University Ave
# 7                                  438 University Ave
# 8                                  393 University Ave
# 9                                  Queen & University
# 10                 Ryerson University Security Centre
# 11                     Lakehead University Book Store
# 12                            University & Wellington
# 13                                 181 University Ave
# 14                              University Eye Clinic
# 15                                505 University Ave.
# 16  Ryerson University Department of Architectural...
# 17                    Ryerson University Campus Store
# 18  Ontario College of Art and Design University (...
# 19                                  King & University
# 20                Simulation Lab @ Ryerson University
# 21                              100 University Avenue
# 22          University of Toronto Engineering Society
# 23                              425 University Avenue
# 24                University at St. Michael's College
# 25     University Of Toronto Residence Parking Garage
# 26                      University College Art Centre
# 27                  University of Toronto Arts Centre
# 28                            University-Spadina Line
# 29                University College Residence Office
# 30                                 University College
# 31                                 Ryerson University
# 32                        University Centre File Room
# 33                      University Centre Tenth Floor
# 34  University of Liverpool Online Degress - Infor...
# 35                              University Ave Island
# 36                          University tobacco Centre
# 37                       University Ave And Edward St
# 38                                    University Club
# 39                                  University Square
# 40                             University Convenience
# 41                               University Plaza Gym
# 42                                 488 University Ave
# 43                                  University Avenue
# 44                                University Parkette
# 45  University Health Network Spiritual Care Depar...
# 46                                   University Plaza
# 47                                Dundas & University
# 48          University Of Toronto - St. George Campus
# 49            University Settlement Recreation Centre
#
#                                   categories        lat        lng  \
# 0                       Gym / Fitness Center  43.653571 -79.386979
# 1                                 University  43.662493 -79.395220
# 2                                     Office  43.653907 -79.386764
# 3                             Medical Center  43.654196 -79.388166
# 4                                      Plaza  43.652695 -79.387218
# 5                           Dentist's Office  43.656260 -79.387143
# 6                                     Office  43.655099 -79.388648
# 7                                     Office  43.654296 -79.388415
# 8                                     Office  43.653752 -79.388150
# 9                               Intersection  43.650833 -79.386858
# 10                        Miscellaneous Shop  43.652981 -79.378340
# 11                                 Bookstore  43.655428 -79.389002
# 12                              Intersection  43.646385 -79.384878
# 13                                  Building  43.649282 -79.385788
# 14                           Doctor's Office  43.659280 -79.390281
# 15                       Government Building  43.656177 -79.388549
# 16                 College Academic Building  43.659307 -79.378096
# 17                         College Bookstore  43.657500 -79.380041
# 18                                University  43.652803 -79.391074
# 19                              Intersection  43.647818 -79.384968
# 20                               College Lab  43.659746 -79.382041
# 21                                    Office  43.647185 -79.384367
# 22                            Student Center  43.660097 -79.394644
# 23                                    Office  43.653769 -79.383949
# 24                                University  43.665711 -79.389909
# 25                                  Building  43.654183 -79.385989
# 26                               Art Gallery  43.663962 -79.395385
# 27                               Art Gallery  43.663605 -79.395159
# 28                             Metro Station  43.668202 -79.399601
# 29                                University  43.663331 -79.397947
# 30                                University  43.662695 -79.396061
# 31                                University  43.657935 -79.380490
# 32                                  Building  43.654095 -79.387733
# 33                                  Building  43.654099 -79.387895
# 34                                University  43.656586 -79.384042
# 35                                     Plaza  43.654790 -79.388161
# 36                        Miscellaneous Shop  43.654769 -79.388195
# 37                                      Road  43.656125 -79.387886
# 38                               Event Space  43.653145 -79.387711
# 39                                     Plaza  43.650589 -79.386828
# 40                         Food & Drink Shop  43.654878 -79.389127
# 41                      Gym / Fitness Center  43.649792 -79.387363
# 42  Residential Building (Apartment / Condo)  43.655982 -79.388560
# 43                      Other Great Outdoors  43.657787 -79.386742
# 44                                      Park  43.656706 -79.388897
# 45                          Spiritual Center  43.658209 -79.384962
# 46  Residential Building (Apartment / Condo)  43.649394 -79.387095
# 47                              Intersection  43.654620 -79.389150
# 48                 College Academic Building  43.662655 -79.395440
# 49                               College Gym  43.652139 -79.391477
#
#                                        labeledLatLngs  distance  cc country  \
# 0   [{'label': 'display', 'lat': 43.653571, 'lng':...       245  CA  Canada
# 1   [{'label': 'display', 'lat': 43.6624934706167,...      1353  CA  Canada
# 2   [{'label': 'display', 'lat': 43.65390719043468...       232  CA  Canada
# 3   [{'label': 'display', 'lat': 43.65419587934101...       349  CA  Canada
# 4   [{'label': 'display', 'lat': 43.65269470686765...       278  CA  Canada
# 5   [{'label': 'display', 'lat': 43.65626040346387...       403  CA  Canada
# 6   [{'label': 'display', 'lat': 43.65509931314145...       420  CA  Canada
# 7   [{'label': 'display', 'lat': 43.65429570830456...       372  CA  Canada
# 8   [{'label': 'display', 'lat': 43.65375248805427...       340  CA  Canada
# 9   [{'label': 'display', 'lat': 43.65083280275225...       377  CA  Canada
# 10  [{'label': 'display', 'lat': 43.65298107973972...       454  CA  Canada
# 11  [{'label': 'display', 'lat': 43.65542796114875...       462  CA  Canada
# 12  [{'label': 'display', 'lat': 43.64638522569841...       793  CA  Canada
# 13  [{'label': 'display', 'lat': 43.64928171051231...       490  CA  Canada
# 14  [{'label': 'display', 'lat': 43.65927999991696...       823  CA  Canada
# 15  [{'label': 'display', 'lat': 43.65617732807896...       477  CA  Canada
# 16  [{'label': 'display', 'lat': 43.65930687078133...       801  CA  Canada
# 17  [{'label': 'display', 'lat': 43.65750025281336...       546  CA  Canada
# 18  [{'label': 'display', 'lat': 43.65280251171013...       579  CA  Canada
# 19  [{'label': 'display', 'lat': 43.64781757077785...       635  CA  Canada
# 20  [{'label': 'display', 'lat': 43.65974555361321...       713  CA  Canada
# 21  [{'label': 'display', 'lat': 43.6471854998311,...       701  CA  Canada
# 22  [{'label': 'display', 'lat': 43.660097244179, ...      1134  CA  Canada
# 23  [{'label': 'display', 'lat': 43.65376907416923...        32  CA  Canada
# 24  [{'label': 'display', 'lat': 43.66571145228362...      1443  CA  Canada
# 25  [{'label': 'display', 'lat': 43.65418264783643...       182  CA  Canada
# 26  [{'label': 'display', 'lat': 43.66396220617091...      1487  CA  Canada
# 27  [{'label': 'display', 'lat': 43.66360538340076...      1444  CA  Canada
# 28  [{'label': 'display', 'lat': 43.66820177496591...      2068  CA  Canada
# 29  [{'label': 'display', 'lat': 43.66333075902387...      1573  CA  Canada
# 30  [{'label': 'display', 'lat': 43.66269528389713...      1416  CA  Canada
# 31  [{'label': 'display', 'lat': 43.65793504826254...       568  CA  Canada
# 32  [{'label': 'display', 'lat': 43.654095, 'lng':...       313  CA  Canada
# 33  [{'label': 'display', 'lat': 43.654099, 'lng':...       326  CA  Canada
# 34  [{'label': 'display', 'lat': 43.65658641717643...       345  CA  Canada
# 35  [{'label': 'display', 'lat': 43.65479007247406...       370  CA  Canada
# 36  [{'label': 'display', 'lat': 43.654769, 'lng':...       371  CA  Canada
# 37  [{'label': 'display', 'lat': 43.6561251758947,...       433  CA  Canada
# 38  [{'label': 'display', 'lat': 43.65314503023699...       306  CA  Canada
# 39  [{'label': 'display', 'lat': 43.65058906857442...       397  CA  Canada
# 40  [{'label': 'display', 'lat': 43.6548775434494,...       446  CA  Canada
# 41  [{'label': 'display', 'lat': 43.64979247531880...       494  CA  Canada
# 42  [{'label': 'display', 'lat': 43.655982, 'lng':...       465  CA  Canada
# 43  [{'label': 'display', 'lat': 43.65778707930200...       529  CA  Canada
# 44  [{'label': 'display', 'lat': 43.65670638506665...       537  CA  Canada
# 45  [{'label': 'display', 'lat': 43.658209, 'lng':...       532  CA  Canada
# 46  [{'label': 'display', 'lat': 43.6493938770396,...       521  CA  Canada
# 47  [{'label': 'display', 'lat': 43.65462, 'lng': ...       438  CA  Canada
# 48  [{'label': 'display', 'lat': 43.662655, 'lng':...      1378  CA  Canada
# 49  [{'label': 'display', 'lat': 43.65213850602077...       625  CA  Canada
#
#                                      formattedAddress  \
# 0                                            [Canada]
# 1   [27 King's College Cir (at King's College Rd),...
# 2   [393 University Ave. (at Armoury St.), Toronto...
# 3   [104-438 University Avenue, Toronto ON M4P 2K8...
# 4   [University Avenue (btwn Richmond & College), ...
# 5     [124 Edward Street, Toronto ON M5G 2L3, Canada]
# 6   [480 University Ave (Dundas), Toronto ON M5G 1...
# 7   [438 University Ave (at Dundas St W), Toronto ...
# 8    [393 University Ave, Toronto ON M5G 1E6, Canada]
# 9   [Queen St W (& University Ave), Toronto ON, Ca...
# 10                 [111 Bond St., Toronto ON, Canada]
# 11        [500 University Avenue, Orillia ON, Canada]
# 12                               [Toronto ON, Canada]
# 13                               [Toronto ON, Canada]
# 14  [700 University Ave, Suite 3 (College Street),...
# 15          [505 University Ave., Toronto ON, Canada]
# 16  [325 Church St., ARC-203 (at Ryerson Universit...
# 17  [17 Gould St. (at Victoria St.), Toronto ON M5...
# 18  [100 McCaul St (at Dundas St W), Toronto ON M5...
# 19            [King (University), Toronto ON, Canada]
# 20  [415 Yonge Street, 3rd Floor (Gerrard St. E. &...
# 21        [100 University Avenue, Toronto ON, Canada]
# 22  [10 King's College Rd. - B740 (at Galbraith Rd...
# 23  [425 University Avenue (Dundas St W), Toronto ...
# 24           [St Joseph St (Bay), Toronto ON, Canada]
# 25           [89 Chestnut Street, Toronto ON, Canada]
# 26  [King College Circle and Tower Rd, Toronto ON,...
# 27      [15 Kings College Circle, Toronto ON, Canada]
# 28                                           [Canada]
# 29         [79 St. George street, Toronto ON, Canada]
# 30  [15 King's College Circle (University of Toron...
# 31  [350 Victoria St. (at Gould St.), Toronto ON M...
# 32           [393 university ave, Toronto ON, Canada]
# 33                               [Toronto ON, Canada]
# 34  [Toronto Marriot Downtown Eaton Centre Hotel (...
# 35               [0 (Dundas Ave), Toronto ON, Canada]
# 36           [481 University Ave, Toronto ON, Canada]
# 37                               [Toronto ON, Canada]
# 38           [380 university Ave, Toronto ON, Canada]
# 39                               [Toronto ON, Canada]
# 40  [481 University Ave. (at Dundas), Toronto ON, ...
# 41      [140 Simcoe St (Richmond And Simcoe), Canada]
# 42  [488 University Ave (Dundas St W), Toronto ON,...
# 43                                           [Canada]
# 44                               [Toronto ON, Canada]
# 45           [700 Bay St, Toronto ON M5G 0A2, Canada]
# 46                               [Toronto ON, Canada]
# 47  [University Ave (Dundas), Toronto ON M5G 1V1, ...
# 48                       [Toronto ON M5S 3H7, Canada]
# 49  [23 Grange Rd. (Dundas and McCaul), Toronto ON...
#
#                                         address  \
# 0                                           NaN
# 1                         27 King's College Cir
# 2                           393 University Ave.
# 3                     104-438 University Avenue
# 4                             University Avenue
# 5                             124 Edward Street
# 6                            480 University Ave
# 7                            438 University Ave
# 8                            393 University Ave
# 9                                    Queen St W
# 10                                 111 Bond St.
# 11                        500 University Avenue
# 12                                          NaN
# 13                                          NaN
# 14                  700 University Ave, Suite 3
# 15                          505 University Ave.
# 16                      325 Church St., ARC-203
# 17                                 17 Gould St.
# 18                                100 McCaul St
# 19                                         King
# 20                  415 Yonge Street, 3rd Floor
# 21                        100 University Avenue
# 22                 10 King's College Rd. - B740
# 23                        425 University Avenue
# 24                                 St Joseph St
# 25                           89 Chestnut Street
# 26                                          NaN
# 27                      15 Kings College Circle
# 28                                          NaN
# 29                         79 St. George street
# 30                     15 King's College Circle
# 31                             350 Victoria St.
# 32                           393 university ave
# 33                                          NaN
# 34  Toronto Marriot Downtown Eaton Centre Hotel
# 35                                            0
# 36                           481 University Ave
# 37                                          NaN
# 38                           380 university Ave
# 39                                          NaN
# 40                          481 University Ave.
# 41                                140 Simcoe St
# 42                           488 University Ave
# 43                                          NaN
# 44                                          NaN
# 45                                   700 Bay St
# 46                                          NaN
# 47                               University Ave
# 48                                          NaN
# 49                                23 Grange Rd.
#
#                          crossStreet postalCode     city state  \
# 0                                NaN        NaN      NaN   NaN
# 1               at King's College Rd    M5S 1A1  Toronto    ON
# 2                     at Armoury St.    M7A 2K1  Toronto    ON
# 3                                NaN    M4P 2K8  Toronto    ON
# 4            btwn Richmond & College        NaN  Toronto    ON
# 5                                NaN    M5G 2L3  Toronto    ON
# 6                             Dundas    M5G 1V2  Toronto    ON
# 7                     at Dundas St W    M5G 2K8  Toronto    ON
# 8                                NaN    M5G 1E6  Toronto    ON
# 9                   & University Ave        NaN  Toronto    ON
# 10                               NaN        NaN  Toronto    ON
# 11                               NaN        NaN  Orillia    ON
# 12                               NaN        NaN  Toronto    ON
# 13                               NaN        NaN  Toronto    ON
# 14                    College Street    M5G 1Z5  Toronto    ON
# 15                               NaN        NaN  Toronto    ON
# 16             at Ryerson University    M5B 2K3  Toronto    ON
# 17                   at Victoria St.    M5B 2K3  Toronto    ON
# 18                    at Dundas St W    M5T 1W1  Toronto    ON
# 19                        University        NaN  Toronto    ON
# 20        Gerrard St. E. & Yonge St.        NaN  Toronto    ON
# 21                               NaN        NaN  Toronto    ON
# 22                  at Galbraith Rd.    M5S 3G4  Toronto    ON
# 23                       Dundas St W    M5G 1T6  Toronto    ON
# 24                               Bay        NaN  Toronto    ON
# 25                               NaN        NaN  Toronto    ON
# 26  King College Circle and Tower Rd        NaN  Toronto    ON
# 27                               NaN        NaN  Toronto    ON
# 28                               NaN        NaN      NaN   NaN
# 29                               NaN        NaN  Toronto    ON
# 30             University of Toronto    M5S 3H7  Toronto    ON
# 31                      at Gould St.    M5B 2K3  Toronto    ON
# 32                               NaN        NaN  Toronto    ON
# 33                               NaN        NaN  Toronto    ON
# 34                    525 Bay Street        NaN  Toronto    ON
# 35                        Dundas Ave        NaN  Toronto    ON
# 36                               NaN        NaN  Toronto    ON
# 37                               NaN        NaN  Toronto    ON
# 38                               NaN        NaN  Toronto    ON
# 39                               NaN        NaN  Toronto    ON
# 40                         at Dundas        NaN  Toronto    ON
# 41               Richmond And Simcoe        NaN      NaN   NaN
# 42                       Dundas St W        NaN  Toronto    ON
# 43                               NaN        NaN      NaN   NaN
# 44                               NaN        NaN  Toronto    ON
# 45                               NaN    M5G 0A2  Toronto    ON
# 46                               NaN        NaN  Toronto    ON
# 47                            Dundas    M5G 1V1  Toronto    ON
# 48                               NaN    M5S 3H7  Toronto    ON
# 49                 Dundas and McCaul    M5T 1C3  Toronto    ON
#
#               neighborhood                        id
# 0                      NaN  4cd044c29d87224bf129543b
# 1                      NaN  4ad4c05ef964a52097f620e3
# 2                      NaN  4c45c6c6da2176b09543637a
# 3                      NaN  4c6062b612e5c9286e131f4c
# 4                      NaN  4e6565fb1850e238d7048495
# 5                      NaN  5633a320498e59191a412f3d
# 6                      NaN  4b13d2cff964a5207f9923e3
# 7                      NaN  4d5d275fff226a3110517e69
# 8                      NaN  4c655857f67ec928e7485727
# 9                      NaN  4c053af4187ec928411db87b
# 10                     NaN  502ebc1ce4b0d68f376457b9
# 11                     NaN  4f0c5654e4b087b6f750937a
# 12                     NaN  51433917e4b03cf305c043d3
# 13                     NaN  4e243f4fe4cdf68591a0df9d
# 14                     NaN  4c48b7c1b5eec9b63200caa3
# 15                     NaN  4ae85d05f964a520e2ae21e3
# 16                     NaN  4afc9ba3f964a5205e2422e3
# 17                     NaN  4b82c2d4f964a52010e330e3
# 18                     NaN  4ad4c064f964a52065f820e3
# 19  Entertainment District  4c4469cb8c1f20a1de563c99
# 20                     NaN  4e5c344f1520cd7bd644f933
# 21      Financial District  5254687611d247f32d3bcaf0
# 22                     NaN  4c850e1b2f1c236ad9e85043
# 23                     NaN  4f144a09e4b0456269f68c59
# 24                     NaN  4b957655f964a520d2a334e3
# 25                     NaN  4be2a144d27a20a11fee8f5b
# 26                     NaN  4d8a79ae6ce6a35de4a26142
# 27                     NaN  4bfd97014cf820a1c0b0ecf4
# 28                     NaN  50b3eee5e4b0ed0fc2780e7b
# 29                     NaN  4bbe3fdd1416a5931ce3f33c
# 30                     NaN  4ad893f7f964a5207c1221e3
# 31                     NaN  4ad7797cf964a520170b21e3
# 32                     NaN  4e395cffb0fb2f7ee8661071
# 33                     NaN  4e395c8862e16ad099f14646
# 34                     NaN  4e087c74b3ad23ff54003709
# 35                     NaN  4fb67e68e4b0a804114ec42a
# 36                     NaN  4cd0434c7b6854818178c0f8
# 37                     NaN  4e7de44a29c294ffa2d4ce89
# 38                     NaN  4baa40a2f964a520d5573ae3
# 39                     NaN  4e4e92921f6eae4d250d348d
# 40                     NaN  4c49c1136f1420a1e2e60c56
# 41                     NaN  4f09cbb2e4b0ca3a5da2e59c
# 42                     NaN  5706a95dcd10b38b56da75d3
# 43                     NaN  5756b9c4498ea46881c6631c
# 44                     NaN  4e3eeac318a83d5b285881d9
# 45                     NaN  59073d7b780eee19af8852d5
# 46                     NaN  4e53f618fa766dacedec3098
# 47                     NaN  51b73fd2498e156dd1dd018a
# 48                     NaN  58445078c7ec6b39be558738
# 49                     NaN  4ba781a6f964a520f09839e3

# %%
dataframe_filtered.name
# Out:
# 0                                 University Centre Gym
# 1                                 University of Toronto
# 2                                     University Centre
# 3                       Dundas University Health Clinic
# 4                               University Avenue Plaza
# 5               University of Toronto Dentistry Faculty
# 6                                    480 University Ave
# 7                                    438 University Ave
# 8                                    393 University Ave
# 9                                    Queen & University
# 10                   Ryerson University Security Centre
# 11                       Lakehead University Book Store
# 12                              University & Wellington
# 13                                   181 University Ave
# 14                                University Eye Clinic
# 15                                  505 University Ave.
# 16    Ryerson University Department of Architectural...
# 17                      Ryerson University Campus Store
# 18    Ontario College of Art and Design University (...
# 19                                    King & University
# 20                  Simulation Lab @ Ryerson University
# 21                                100 University Avenue
# 22            University of Toronto Engineering Society
# 23                                425 University Avenue
# 24                  University at St. Michael's College
# 25       University Of Toronto Residence Parking Garage
# 26                        University College Art Centre
# 27                    University of Toronto Arts Centre
# 28                              University-Spadina Line
# 29                  University College Residence Office
# 30                                   University College
# 31                                   Ryerson University
# 32                          University Centre File Room
# 33                        University Centre Tenth Floor
# 34    University of Liverpool Online Degress - Infor...
# 35                                University Ave Island
# 36                            University tobacco Centre
# 37                         University Ave And Edward St
# 38                                      University Club
# 39                                    University Square
# 40                               University Convenience
# 41                                 University Plaza Gym
# 42                                   488 University Ave
# 43                                    University Avenue
# 44                                  University Parkette
# 45    University Health Network Spiritual Care Depar...
# 46                                     University Plaza
# 47                                  Dundas & University
# 48            University Of Toronto - St. George Campus
# 49              University Settlement Recreation Centre
# Name: name, dtype: object

# %%
Venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Toronto Downtown

# add a red circle marker to represent the Torornto Downtown
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(Venues_map)

# add the University related buildings as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
Venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4ad4c05ef964a52097f620e3' # ID of University of Toronto
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad4c05ef964a52097f620e3?client_id=HTEQQEAY2ZKJEFL1UTEQMSBQKNTDMEJ4TF4DBLCLGFS2D0YK&client_secret=FYIR54J22WICJ0RA0XBYE4C0SX20JJADKI3XFDODWE4ICGHZ&v=20201122'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'venueRatingBlacklisted', 'beenHere', 'specials', 'photos', 'venuePage', 'reasons', 'description', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad4c05ef964a52097f620e3',
#  'name': 'University of Toronto',
#  'contact': {'phone': '4169782011',
#   'formattedPhone': '(416) 978-2011',
#   'twitter': 'uoft',
#   'facebook': '6169515998',
#   'facebookUsername': 'universitytoronto',
#   'facebookName': 'University of Toronto'},
#  'location': {'address': "27 King's College Cir",
#   'crossStreet': "at King's College Rd",
#   'lat': 43.6624934706167,
#   'lng': -79.39521976633822,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.6624934706167,
#     'lng': -79.39521976633822}],
#   'postalCode': 'M5S 1A1',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ["27 King's College Cir (at King's College Rd)",
#    'Toronto ON M5S 1A1',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/uoft',
#  'categories': [{'id': '4bf58dd8d48988d1ae941735',
#    'name': 'University',
#    'pluralName': 'Universities',
#    'shortName': 'University',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 22},
#  'url': 'http://utoronto.ca',
#  'likes': {'count': 213,
#   'groups': [{'type': 'others', 'count': 213, 'items': []}],
#   'summary': '213 Likes'},
#  'dislike': False,
#  'ok': False,
#  'venueRatingBlacklisted': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 619,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 619,
#     'items': [{'id': '502eb8c0e4b06888b69762e5',
#       'createdAt': 1345239232,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/hbdyDeGHcQTnJjNLJbvOwcPXxaxZYCtKny6uBrIw1LY.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'isSanctioned': False,
#        'firstName': 'Mary',
#        'lastName': 'K',
#        'countryCode': 'CA'},
#       'visibility': 'public'}]}]},
#  'venuePage': {'id': '57112483'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'The downtown Toronto (St. George) campus blends historical architecture & inviting green spaces as a backdrop to a truly remarkable community.',
#  'page': {'user': {'isSanctioned': False,
#    'firstName': 'University of Toronto',
#    'countryCode': 'CA',
#    'type': 'venuePage',
#    'venue': {'id': '4ad4c05ef964a52097f620e3'},
#    'tips': {'count': 0},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255456862,
#  'tips': {'count': 22,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 22,
#     'items': [{'id': '51151994e4b043d2b55705d4',
#       'createdAt': 1360337300,
#       'text': "Never closes for weather. Doesn't matter if it's a tornado or snow, it won't close.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/51151994e4b043d2b55705d4',
#       'lang': 'en',
#       'likes': {'count': 15,
#        'groups': [{'type': 'others', 'count': 15, 'items': []}],
#        'summary': '15 likes'},
#       'logView': True,
#       'agreeCount': 15,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'isSanctioned': False,
#        'firstName': 'Denny',
#        'lastName': 'Y',
#        'countryCode': 'CA'}}]}]},
#  'shortUrl': 'http://4sq.com/9I2eEp',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 90,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 90,
#     'items': [{'id': '4f536f5ae4b092980eec4279',
#       'name': 'Historic Toronto',
#       'description': 'In 1793, Toronto, then known as York, was named capital of the new colony of Upper Canada.',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Sebastian Mark',
#        'lastName': 'K',
#        'countryCode': 'CA'},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/bastian_mark/list/historic-toronto',
#       'canonicalUrl': 'https://foursquare.com/bastian_mark/list/historic-toronto',
#       'createdAt': 1330868058,
#       'updatedAt': 1336422774,
#       'photo': {'id': '4f1acf56e4b0b4fde89a7e58',
#        'createdAt': 1327157078,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3ZR0JOK0P1VUHAKAGHR5XJUX35A1A52W0NBPFIECJZ1KFRLY.jpg',
#        'width': 720,
#        'height': 540,
#        'user': {'isSanctioned': False,
#         'firstName': 'Hamish',
#         'lastName': 'L',
#         'countryCode': 'CA'},
#        'visibility': 'public'},
#       'followers': {'count': 48},
#       'listItems': {'count': 44,
#        'items': [{'id': 'v4ad4c05ef964a52097f620e3',
#          'createdAt': 1330870848,
#          'photo': {'id': '4f25973be4b0d609c7b8d5d7',
#           'createdAt': 1327863611,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/1A3Z0VP5H5GRTPRNNV5O1ILPEOWT01Z3A4FPUJEBKUG5WROL.jpg',
#           'width': 720,
#           'height': 540,
#           'user': {'isSanctioned': False,
#            'firstName': 'Hironori',
#            'lastName': 'E',
#            'countryCode': 'JP'},
#           'visibility': 'public'}}]}},
#      {'id': '4ebe21910e019a1629fe54f0',
#       'name': 'Canada',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'Andy',
#        'lastName': 'S',
#        'countryCode': 'CA'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/theandysparks/list/canada',
#       'canonicalUrl': 'https://foursquare.com/theandysparks/list/canada',
#       'createdAt': 1321083281,
#       'updatedAt': 1594621925,
#       'photo': {'id': '4e49938a315100ba6f71fb06',
#        'createdAt': 1313444746,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/TC3CVGJCQBAALUFFXZQZRMCEGHEB0P2P1D0QDTPSQI1KZSDC.jpg',
#        'width': 1024,
#        'height': 768,
#        'user': {'isSanctioned': False,
#         'firstName': 'Gay Friends In Calgary',
#         'countryCode': 'CA',
#         'type': 'chain'},
#        'visibility': 'public'},
#       'followers': {'count': 32},
#       'listItems': {'count': 48, 'items': []}},
#      {'id': '521e109611d29a7d0b2c5f09',
#       'name': '#TIFF13 Festival Village',
#       'description': '',
#       'type': 'others',
#       'user': {'isSanctioned': False,
#        'firstName': 'TIFF',
#        'countryCode': 'CA',
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/tiff_net/list/tiff13-festival-village',
#       'canonicalUrl': 'https://foursquare.com/tiff_net/list/tiff13-festival-village',
#       'createdAt': 1377702038,
#       'updatedAt': 1377718564,
#       'photo': {'id': '5076b1e7e4b0ace35a5af4e6',
#        'createdAt': 1349956071,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/17718_CJ39ihzWaEpnZ5EJP1Ybwed9SJgeHzeY_9wmvPCp7Dw.jpg',
#        'width': 612,
#        'height': 612,
#        'user': {'isSanctioned': False,
#         'firstName': 'Steve',
#         'lastName': 'G',
#         'countryCode': 'US'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 31},
#       'listItems': {'count': 31,
#        'items': [{'id': 'v4ad4c05ef964a52097f620e3',
#          'createdAt': 1377702074,
#          'photo': {'id': '520ba2de11d2db1156cbd520',
#           'createdAt': 1376494302,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/48345099_nchYoUQmOx9MyHkMsxjiTWWrRWYdLiKGUNgUkO4QcsQ.jpg',
#           'width': 612,
#           'height': 612,
#           'user': {'isSanctioned': False,
#            'firstName': 'Alexandru',
#            'lastName': 'A',
#            'countryCode': 'US'},
#           'visibility': 'public'}}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '1:00 PM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Mon–Tue',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '9:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '9:00 AM–8:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–6:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Yes'}]}]},
#  'bestPhoto': {'id': '502eb8c0e4b06888b69762e5',
#   'createdAt': 1345239232,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/hbdyDeGHcQTnJjNLJbvOwcPXxaxZYCtKny6uBrIw1LY.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '502eb8c0e4b06888b69762e5',
#    'value': -14675928},
#   'highlightTextColor': {'photoId': '502eb8c0e4b06888b69762e5', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
result['response']['venue']['tips']['count']
# Out:
# 22

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fba8ee32158a34dc82e7b21'},
#  'response': {'tips': {'count': 22,
#    'items': [{'id': '4f9b7f35e4b017ea4a35125b',
#      'createdAt': 1335590709,
#      'text': 'Went around the campus and paid a visit to their library. Amazed by the old school, Hogwarts-esque feel of the buildings.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4f9b7f35e4b017ea4a35125b',
#      'lang': 'en',
#      'likes': {'count': 11,
#       'groups': [{'type': 'others', 'count': 11, 'items': []}],
#       'summary': '11 likes'},
#      'logView': True,
#      'agreeCount': 19,
#      'disagreeCount': 0,
#      'todo': {'count': 1},
#      'user': {'isSanctioned': False,
#       'firstName': 'Lesly',
#       'lastName': 'T',
#       'countryCode': 'JP'}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
tips
# Out:
# [{'id': '4f9b7f35e4b017ea4a35125b',
#   'createdAt': 1335590709,
#   'text': 'Went around the campus and paid a visit to their library. Amazed by the old school, Hogwarts-esque feel of the buildings.',
#   'type': 'user',
#   'canonicalUrl': 'https://foursquare.com/item/4f9b7f35e4b017ea4a35125b',
#   'lang': 'en',
#   'likes': {'count': 11,
#    'groups': [{'type': 'others', 'count': 11, 'items': []}],
#    'summary': '11 likes'},
#   'logView': True,
#   'agreeCount': 19,
#   'disagreeCount': 0,
#   'todo': {'count': 1},
#   'user': {'isSanctioned': False,
#    'firstName': 'Lesly',
#    'lastName': 'T',
#    'countryCode': 'JP'}}]

# %%
address = 'University of Toronto, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.663461999999996 -79.39775965337452
